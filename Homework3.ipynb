# %% [markdown]
# <a href="https://colab.research.google.com/github/JingchenYan1/Real-Time-ML/blob/main/Homework3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import time
from torch.utils.data import Dataset, DataLoader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

text = """Next character prediction is a fundamental task in the field of natural language processing (NLP) that involves predicting the next character in a sequence of text based on the characters that precede it. This task is essential for various applications, including text auto-completion, spell checking, and even in the development of sophisticated AI models capable of generating human-like text.

At its core, next character prediction relies on statistical models or deep learning algorithms to analyze a given sequence of text and predict which character is most likely to follow. These predictions are based on patterns and relationships learned from large datasets of text during the training phase of the model.

One of the most popular approaches to next character prediction involves the use of Recurrent Neural Networks (RNNs), and more specifically, a variant called Long Short-Term Memory (LSTM) networks. RNNs are particularly well-suited for sequential data like text, as they can maintain information in 'memory' about previous characters to inform the prediction of the next character. LSTM networks enhance this capability by being able to remember long-term dependencies, making them even more effective for next character prediction tasks.

Training a model for next character prediction involves feeding it large amounts of text data, allowing it to learn the probability of each character's appearance following a sequence of characters. During this training process, the model adjusts its parameters to minimize the difference between its predictions and the actual outcomes, thus improving its predictive accuracy over time.

Once trained, the model can be used to predict the next character in a given piece of text by considering the sequence of characters that precede it. This can enhance user experience in text editing software, improve efficiency in coding environments with auto-completion features, and enable more natural interactions with AI-based chatbots and virtual assistants.

In summary, next character prediction plays a crucial role in enhancing the capabilities of various NLP applications, making text-based interactions more efficient, accurate, and human-like. Through the use of advanced machine learning models like RNNs and LSTMs, next character prediction continues to evolve, opening new possibilities for the future of text-based technology."""

chars = sorted(list(set(text)))
vocab_size = len(chars)
print("Vocabulary size:", vocab_size)

char_to_idx = {ch: i for i, ch in enumerate(chars)}
idx_to_char = {i: ch for i, ch in enumerate(chars)}

text_indices = [char_to_idx[ch] for ch in text]
text_tensor = torch.tensor(text_indices, dtype=torch.long)

class TextDataset(Dataset):
    def __init__(self, text_tensor, seq_length):
        self.text_tensor = text_tensor
        self.seq_length = seq_length

    def __len__(self):
        return len(self.text_tensor) - self.seq_length

    def __getitem__(self, idx):
        return self.text_tensor[idx:idx + self.seq_length], self.text_tensor[idx + self.seq_length]

class CharRNN(nn.Module):
    def __init__(self, rnn_type, vocab_size, embed_size, hidden_size, num_layers=1):
        super(CharRNN, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_size)
        self.rnn_type = rnn_type
        if rnn_type == 'RNN':
            self.rnn = nn.RNN(embed_size, hidden_size, num_layers, batch_first=True)
        elif rnn_type == 'LSTM':
            self.rnn = nn.LSTM(embed_size, hidden_size, num_layers, batch_first=True)
        elif rnn_type == 'GRU':
            self.rnn = nn.GRU(embed_size, hidden_size, num_layers, batch_first=True)
        else:
            raise ValueError("Unknown rnn_type")
        self.fc = nn.Linear(hidden_size, vocab_size)

    def forward(self, x):
        x = self.embedding(x)
        if self.rnn_type == 'LSTM':
            out, (h_n, c_n) = self.rnn(x)
        else:
            out, h_n = self.rnn(x)
        out = out[:, -1, :]
        out = self.fc(out)
        return out

def train_epoch(model, dataloader, criterion, optimizer):
    model.train()
    total_loss = 0.0
    for inputs, targets in dataloader:
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * inputs.size(0)
    return total_loss / len(dataloader.dataset)

def evaluate_model(model, dataloader, criterion):
    model.eval()
    total_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, targets in dataloader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            total_loss += loss.item() * inputs.size(0)
            _, predicted = torch.max(outputs, dim=1)
            correct += (predicted == targets).sum().item()
            total += targets.size(0)
    accuracy = correct / total
    return total_loss / len(dataloader.dataset), accuracy

results = {}
num_epochs = 20
batch_size = 32
embed_size = 64
hidden_size = 128
learning_rate = 0.001

for seq_length in [10, 20, 30]:
    dataset = TextDataset(text_tensor, seq_length)
    dataset_size = len(dataset)
    train_size = int(0.8 * dataset_size)
    val_size = dataset_size - train_size
    train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    for rnn_type in ['RNN', 'LSTM', 'GRU']:
        print(f"\nTraining model: {rnn_type}, Sequence length: {seq_length}")
        model = CharRNN(rnn_type, vocab_size, embed_size, hidden_size).to(device)
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)
        criterion = nn.CrossEntropyLoss()

        start_time = time.time()
        for epoch in range(num_epochs):
            train_loss = train_epoch(model, train_loader, criterion, optimizer)
            val_loss, val_acc = evaluate_model(model, val_loader, criterion)
            print(f"Epoch {epoch + 1:2d}/{num_epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")
        elapsed_time = time.time() - start_time

        num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

        results[(rnn_type, seq_length)] = {
            "train_loss": train_loss,
            "val_loss": val_loss,
            "val_acc": val_acc,
            "time": elapsed_time,
            "num_params": num_params
        }
        print(f"{rnn_type} Model (Sequence Length {seq_length}) Training Time: {elapsed_time:.2f} sec, Parameters: {num_params}")
        print("-" * 60)

print("\nFinal results summary:")
for key, res in results.items():
    rnn_type, seq_length = key
    print(f"Model: {rnn_type:3s}, Sequence Length: {seq_length:2d}, Train Loss: {res['train_loss']:.4f}, "
          f"Val Loss: {res['val_loss']:.4f}, Val Acc: {res['val_acc']:.4f}, "
          f"Time: {res['time']:.2f}s, Params: {res['num_params']}")
# Out:
# Device: cuda
# Vocabulary size: 45
#
# Training model: RNN, Sequence length: 10
# Epoch  1/20, Train Loss: 3.1070, Val Loss: 2.6928, Val Acc: 0.2977
# Epoch  2/20, Train Loss: 2.5079, Val Loss: 2.4294, Val Acc: 0.3669
# Epoch  3/20, Train Loss: 2.2711, Val Loss: 2.2895, Val Acc: 0.3899
# Epoch  4/20, Train Loss: 2.0916, Val Loss: 2.2030, Val Acc: 0.4025
# Epoch  5/20, Train Loss: 1.9497, Val Loss: 2.1480, Val Acc: 0.4277
# Epoch  6/20, Train Loss: 1.8276, Val Loss: 2.0818, Val Acc: 0.4298
# Epoch  7/20, Train Loss: 1.7095, Val Loss: 2.0756, Val Acc: 0.4465
# Epoch  8/20, Train Loss: 1.6131, Val Loss: 2.0352, Val Acc: 0.4654
# Epoch  9/20, Train Loss: 1.5196, Val Loss: 2.0185, Val Acc: 0.4696
# Epoch 10/20, Train Loss: 1.4294, Val Loss: 2.0341, Val Acc: 0.4633
# Epoch 11/20, Train Loss: 1.3534, Val Loss: 2.0017, Val Acc: 0.4843
# Epoch 12/20, Train Loss: 1.2779, Val Loss: 1.9867, Val Acc: 0.4717
# Epoch 13/20, Train Loss: 1.2046, Val Loss: 2.0203, Val Acc: 0.4717
# Epoch 14/20, Train Loss: 1.1329, Val Loss: 1.9929, Val Acc: 0.4885
# Epoch 15/20, Train Loss: 1.0581, Val Loss: 1.9967, Val Acc: 0.4738
# Epoch 16/20, Train Loss: 0.9938, Val Loss: 2.0045, Val Acc: 0.4738
# Epoch 17/20, Train Loss: 0.9341, Val Loss: 2.0172, Val Acc: 0.4822
# Epoch 18/20, Train Loss: 0.8680, Val Loss: 2.0512, Val Acc: 0.4801
# Epoch 19/20, Train Loss: 0.8130, Val Loss: 2.0393, Val Acc: 0.4864
# Epoch 20/20, Train Loss: 0.7501, Val Loss: 2.0846, Val Acc: 0.4801
# RNN Model (Sequence Length 10) Training Time: 3.00 sec, Parameters: 33517
# ------------------------------------------------------------
#
# Training model: LSTM, Sequence length: 10
# Epoch  1/20, Train Loss: 3.2301, Val Loss: 2.8555, Val Acc: 0.2013
# Epoch  2/20, Train Loss: 2.6949, Val Loss: 2.5962, Val Acc: 0.2495
# Epoch  3/20, Train Loss: 2.4508, Val Loss: 2.4056, Val Acc: 0.3249
# Epoch  4/20, Train Loss: 2.2625, Val Loss: 2.2838, Val Acc: 0.3753
# Epoch  5/20, Train Loss: 2.1002, Val Loss: 2.2210, Val Acc: 0.3795
# Epoch  6/20, Train Loss: 1.9547, Val Loss: 2.1403, Val Acc: 0.4130
# Epoch  7/20, Train Loss: 1.8208, Val Loss: 2.1046, Val Acc: 0.4319
# Epoch  8/20, Train Loss: 1.7043, Val Loss: 2.0529, Val Acc: 0.4319
# Epoch  9/20, Train Loss: 1.6005, Val Loss: 2.0283, Val Acc: 0.4507
# Epoch 10/20, Train Loss: 1.4891, Val Loss: 2.0023, Val Acc: 0.4549
# Epoch 11/20, Train Loss: 1.3962, Val Loss: 1.9968, Val Acc: 0.4528
# Epoch 12/20, Train Loss: 1.2997, Val Loss: 1.9757, Val Acc: 0.4591
# Epoch 13/20, Train Loss: 1.2136, Val Loss: 1.9527, Val Acc: 0.4738
# Epoch 14/20, Train Loss: 1.1288, Val Loss: 1.9556, Val Acc: 0.4759
# Epoch 15/20, Train Loss: 1.0446, Val Loss: 1.9629, Val Acc: 0.4696
# Epoch 16/20, Train Loss: 0.9728, Val Loss: 1.9636, Val Acc: 0.4780
# Epoch 17/20, Train Loss: 0.8884, Val Loss: 1.9617, Val Acc: 0.4885
# Epoch 18/20, Train Loss: 0.8211, Val Loss: 1.9570, Val Acc: 0.4843
# Epoch 19/20, Train Loss: 0.7523, Val Loss: 1.9726, Val Acc: 0.4969
# Epoch 20/20, Train Loss: 0.6846, Val Loss: 2.0020, Val Acc: 0.4969
# LSTM Model (Sequence Length 10) Training Time: 3.61 sec, Parameters: 108013
# ------------------------------------------------------------
#
# Training model: GRU, Sequence length: 10
# Epoch  1/20, Train Loss: 3.1047, Val Loss: 2.7521, Val Acc: 0.2348
# Epoch  2/20, Train Loss: 2.5667, Val Loss: 2.4743, Val Acc: 0.2809
# Epoch  3/20, Train Loss: 2.3050, Val Loss: 2.3106, Val Acc: 0.3501
# Epoch  4/20, Train Loss: 2.1227, Val Loss: 2.1890, Val Acc: 0.4109
# Epoch  5/20, Train Loss: 1.9635, Val Loss: 2.0972, Val Acc: 0.4214
# Epoch  6/20, Train Loss: 1.8216, Val Loss: 2.0312, Val Acc: 0.4507
# Epoch  7/20, Train Loss: 1.6942, Val Loss: 2.0070, Val Acc: 0.4570
# Epoch  8/20, Train Loss: 1.5768, Val Loss: 1.9748, Val Acc: 0.4696
# Epoch  9/20, Train Loss: 1.4693, Val Loss: 1.9331, Val Acc: 0.4801
# Epoch 10/20, Train Loss: 1.3696, Val Loss: 1.9139, Val Acc: 0.4969
# Epoch 11/20, Train Loss: 1.2826, Val Loss: 1.9141, Val Acc: 0.4969
# Epoch 12/20, Train Loss: 1.1893, Val Loss: 1.8907, Val Acc: 0.4948
# Epoch 13/20, Train Loss: 1.1034, Val Loss: 1.9097, Val Acc: 0.4927
# Epoch 14/20, Train Loss: 1.0290, Val Loss: 1.8910, Val Acc: 0.4906
# Epoch 15/20, Train Loss: 0.9567, Val Loss: 1.9073, Val Acc: 0.4906
# Epoch 16/20, Train Loss: 0.8854, Val Loss: 1.9075, Val Acc: 0.5010
# Epoch 17/20, Train Loss: 0.8150, Val Loss: 1.9116, Val Acc: 0.5073
# Epoch 18/20, Train Loss: 0.7554, Val Loss: 1.9350, Val Acc: 0.5157
# Epoch 19/20, Train Loss: 0.6953, Val Loss: 1.9514, Val Acc: 0.4969
# Epoch 20/20, Train Loss: 0.6365, Val Loss: 1.9437, Val Acc: 0.5094
# GRU Model (Sequence Length 10) Training Time: 3.05 sec, Parameters: 83181
# ------------------------------------------------------------
#
# Training model: RNN, Sequence length: 20
# Epoch  1/20, Train Loss: 3.0582, Val Loss: 2.6878, Val Acc: 0.3032
# Epoch  2/20, Train Loss: 2.5053, Val Loss: 2.4538, Val Acc: 0.3368
# Epoch  3/20, Train Loss: 2.2605, Val Loss: 2.3404, Val Acc: 0.3789
# Epoch  4/20, Train Loss: 2.0966, Val Loss: 2.2446, Val Acc: 0.4189
# Epoch  5/20, Train Loss: 1.9586, Val Loss: 2.1827, Val Acc: 0.4232
# Epoch  6/20, Train Loss: 1.8439, Val Loss: 2.1388, Val Acc: 0.4547
# Epoch  7/20, Train Loss: 1.7387, Val Loss: 2.0978, Val Acc: 0.4547
# Epoch  8/20, Train Loss: 1.6480, Val Loss: 2.0734, Val Acc: 0.4674
# Epoch  9/20, Train Loss: 1.5605, Val Loss: 2.0624, Val Acc: 0.4463
# Epoch 10/20, Train Loss: 1.4852, Val Loss: 2.0242, Val Acc: 0.4611
# Epoch 11/20, Train Loss: 1.4150, Val Loss: 2.0209, Val Acc: 0.4589
# Epoch 12/20, Train Loss: 1.3442, Val Loss: 2.0399, Val Acc: 0.4568
# Epoch 13/20, Train Loss: 1.2731, Val Loss: 2.0127, Val Acc: 0.4716
# Epoch 14/20, Train Loss: 1.2010, Val Loss: 2.0177, Val Acc: 0.4842
# Epoch 15/20, Train Loss: 1.1402, Val Loss: 2.0196, Val Acc: 0.4716
# Epoch 16/20, Train Loss: 1.0799, Val Loss: 2.0176, Val Acc: 0.4947
# Epoch 17/20, Train Loss: 1.0112, Val Loss: 2.0310, Val Acc: 0.4905
# Epoch 18/20, Train Loss: 0.9539, Val Loss: 2.0341, Val Acc: 0.4884
# Epoch 19/20, Train Loss: 0.8953, Val Loss: 2.0474, Val Acc: 0.5032
# Epoch 20/20, Train Loss: 0.8450, Val Loss: 2.0754, Val Acc: 0.5074
# RNN Model (Sequence Length 20) Training Time: 2.86 sec, Parameters: 33517
# ------------------------------------------------------------
#
# Training model: LSTM, Sequence length: 20
# Epoch  1/20, Train Loss: 3.2438, Val Loss: 2.8928, Val Acc: 0.1874
# Epoch  2/20, Train Loss: 2.7441, Val Loss: 2.6175, Val Acc: 0.2695
# Epoch  3/20, Train Loss: 2.4801, Val Loss: 2.4378, Val Acc: 0.3432
# Epoch  4/20, Train Loss: 2.2892, Val Loss: 2.3140, Val Acc: 0.3768
# Epoch  5/20, Train Loss: 2.1323, Val Loss: 2.2088, Val Acc: 0.4084
# Epoch  6/20, Train Loss: 2.0011, Val Loss: 2.1456, Val Acc: 0.4189
# Epoch  7/20, Train Loss: 1.8867, Val Loss: 2.0782, Val Acc: 0.4274
# Epoch  8/20, Train Loss: 1.7840, Val Loss: 2.0597, Val Acc: 0.4463
# Epoch  9/20, Train Loss: 1.6820, Val Loss: 1.9892, Val Acc: 0.4674
# Epoch 10/20, Train Loss: 1.5869, Val Loss: 1.9656, Val Acc: 0.4863
# Epoch 11/20, Train Loss: 1.4923, Val Loss: 1.9354, Val Acc: 0.4800
# Epoch 12/20, Train Loss: 1.4040, Val Loss: 1.9080, Val Acc: 0.4821
# Epoch 13/20, Train Loss: 1.3215, Val Loss: 1.8972, Val Acc: 0.4968
# Epoch 14/20, Train Loss: 1.2423, Val Loss: 1.8960, Val Acc: 0.4800
# Epoch 15/20, Train Loss: 1.1660, Val Loss: 1.8832, Val Acc: 0.4947
# Epoch 16/20, Train Loss: 1.0841, Val Loss: 1.8661, Val Acc: 0.4989
# Epoch 17/20, Train Loss: 1.0162, Val Loss: 1.9045, Val Acc: 0.5032
# Epoch 18/20, Train Loss: 0.9460, Val Loss: 1.8833, Val Acc: 0.5137
# Epoch 19/20, Train Loss: 0.8752, Val Loss: 1.8861, Val Acc: 0.5074
# Epoch 20/20, Train Loss: 0.8076, Val Loss: 1.9054, Val Acc: 0.5032
# LSTM Model (Sequence Length 20) Training Time: 3.49 sec, Parameters: 108013
# ------------------------------------------------------------
#
# Training model: GRU, Sequence length: 20
# Epoch  1/20, Train Loss: 3.1376, Val Loss: 2.8031, Val Acc: 0.2358
# Epoch  2/20, Train Loss: 2.6107, Val Loss: 2.5545, Val Acc: 0.2800
# Epoch  3/20, Train Loss: 2.3482, Val Loss: 2.3605, Val Acc: 0.3516
# Epoch  4/20, Train Loss: 2.1503, Val Loss: 2.2287, Val Acc: 0.4063
# Epoch  5/20, Train Loss: 1.9879, Val Loss: 2.1362, Val Acc: 0.4168
# Epoch  6/20, Train Loss: 1.8487, Val Loss: 2.0616, Val Acc: 0.4547
# Epoch  7/20, Train Loss: 1.7221, Val Loss: 2.0074, Val Acc: 0.4674
# Epoch  8/20, Train Loss: 1.6021, Val Loss: 1.9595, Val Acc: 0.4863
# Epoch  9/20, Train Loss: 1.4947, Val Loss: 1.9298, Val Acc: 0.4947
# Epoch 10/20, Train Loss: 1.3906, Val Loss: 1.9065, Val Acc: 0.5032
# Epoch 11/20, Train Loss: 1.2964, Val Loss: 1.9010, Val Acc: 0.5116
# Epoch 12/20, Train Loss: 1.2056, Val Loss: 1.8918, Val Acc: 0.5200
# Epoch 13/20, Train Loss: 1.1173, Val Loss: 1.8758, Val Acc: 0.5221
# Epoch 14/20, Train Loss: 1.0380, Val Loss: 1.8876, Val Acc: 0.5221
# Epoch 15/20, Train Loss: 0.9632, Val Loss: 1.8610, Val Acc: 0.5347
# Epoch 16/20, Train Loss: 0.8877, Val Loss: 1.8803, Val Acc: 0.5347
# Epoch 17/20, Train Loss: 0.8197, Val Loss: 1.9102, Val Acc: 0.5389
# Epoch 18/20, Train Loss: 0.7478, Val Loss: 1.9040, Val Acc: 0.5516
# Epoch 19/20, Train Loss: 0.6886, Val Loss: 1.9338, Val Acc: 0.5516
# Epoch 20/20, Train Loss: 0.6370, Val Loss: 1.9374, Val Acc: 0.5537
# GRU Model (Sequence Length 20) Training Time: 3.26 sec, Parameters: 83181
# ------------------------------------------------------------
#
# Training model: RNN, Sequence length: 30
# Epoch  1/20, Train Loss: 3.1098, Val Loss: 2.7446, Val Acc: 0.2495
# Epoch  2/20, Train Loss: 2.5515, Val Loss: 2.4746, Val Acc: 0.3404
# Epoch  3/20, Train Loss: 2.3056, Val Loss: 2.3263, Val Acc: 0.3932
# Epoch  4/20, Train Loss: 2.1235, Val Loss: 2.2497, Val Acc: 0.4355
# Epoch  5/20, Train Loss: 1.9801, Val Loss: 2.1518, Val Acc: 0.4482
# Epoch  6/20, Train Loss: 1.8439, Val Loss: 2.0827, Val Acc: 0.4630
# Epoch  7/20, Train Loss: 1.7381, Val Loss: 2.0532, Val Acc: 0.4609
# Epoch  8/20, Train Loss: 1.6326, Val Loss: 2.0216, Val Acc: 0.4630
# Epoch  9/20, Train Loss: 1.5420, Val Loss: 2.0002, Val Acc: 0.4715
# Epoch 10/20, Train Loss: 1.4491, Val Loss: 1.9901, Val Acc: 0.4841
# Epoch 11/20, Train Loss: 1.3691, Val Loss: 1.9843, Val Acc: 0.4841
# Epoch 12/20, Train Loss: 1.2940, Val Loss: 2.0158, Val Acc: 0.4841
# Epoch 13/20, Train Loss: 1.2180, Val Loss: 1.9797, Val Acc: 0.5074
# Epoch 14/20, Train Loss: 1.1430, Val Loss: 2.0028, Val Acc: 0.5011
# Epoch 15/20, Train Loss: 1.0798, Val Loss: 2.0199, Val Acc: 0.4905
# Epoch 16/20, Train Loss: 1.0167, Val Loss: 2.0124, Val Acc: 0.4989
# Epoch 17/20, Train Loss: 0.9567, Val Loss: 2.0110, Val Acc: 0.5137
# Epoch 18/20, Train Loss: 0.8971, Val Loss: 2.0406, Val Acc: 0.4947
# Epoch 19/20, Train Loss: 0.8410, Val Loss: 2.0625, Val Acc: 0.5032
# Epoch 20/20, Train Loss: 0.7858, Val Loss: 2.1023, Val Acc: 0.5095
# RNN Model (Sequence Length 30) Training Time: 2.85 sec, Parameters: 33517
# ------------------------------------------------------------
#
# Training model: LSTM, Sequence length: 30
# Epoch  1/20, Train Loss: 3.1986, Val Loss: 2.9141, Val Acc: 0.2030
# Epoch  2/20, Train Loss: 2.7325, Val Loss: 2.6333, Val Acc: 0.2685
# Epoch  3/20, Train Loss: 2.4701, Val Loss: 2.4455, Val Acc: 0.3552
# Epoch  4/20, Train Loss: 2.2737, Val Loss: 2.3329, Val Acc: 0.3721
# Epoch  5/20, Train Loss: 2.1158, Val Loss: 2.2386, Val Acc: 0.3996
# Epoch  6/20, Train Loss: 1.9989, Val Loss: 2.1391, Val Acc: 0.4461
# Epoch  7/20, Train Loss: 1.8707, Val Loss: 2.0901, Val Acc: 0.4524
# Epoch  8/20, Train Loss: 1.7728, Val Loss: 2.0669, Val Acc: 0.4503
# Epoch  9/20, Train Loss: 1.6693, Val Loss: 2.0294, Val Acc: 0.4799
# Epoch 10/20, Train Loss: 1.5814, Val Loss: 1.9933, Val Acc: 0.4715
# Epoch 11/20, Train Loss: 1.4970, Val Loss: 1.9624, Val Acc: 0.4884
# Epoch 12/20, Train Loss: 1.4109, Val Loss: 1.9695, Val Acc: 0.4968
# Epoch 13/20, Train Loss: 1.3349, Val Loss: 1.9622, Val Acc: 0.4947
# Epoch 14/20, Train Loss: 1.2564, Val Loss: 1.9459, Val Acc: 0.4989
# Epoch 15/20, Train Loss: 1.1789, Val Loss: 1.9280, Val Acc: 0.5032
# Epoch 16/20, Train Loss: 1.1063, Val Loss: 1.9406, Val Acc: 0.5201
# Epoch 17/20, Train Loss: 1.0378, Val Loss: 1.9452, Val Acc: 0.5074
# Epoch 18/20, Train Loss: 0.9757, Val Loss: 1.9507, Val Acc: 0.5053
# Epoch 19/20, Train Loss: 0.9067, Val Loss: 1.9525, Val Acc: 0.5137
# Epoch 20/20, Train Loss: 0.8496, Val Loss: 1.9472, Val Acc: 0.5053
# LSTM Model (Sequence Length 30) Training Time: 3.10 sec, Parameters: 108013
# ------------------------------------------------------------
#
# Training model: GRU, Sequence length: 30
# Epoch  1/20, Train Loss: 3.1198, Val Loss: 2.8084, Val Acc: 0.2410
# Epoch  2/20, Train Loss: 2.5990, Val Loss: 2.5117, Val Acc: 0.3129
# Epoch  3/20, Train Loss: 2.3347, Val Loss: 2.3317, Val Acc: 0.3932
# Epoch  4/20, Train Loss: 2.1490, Val Loss: 2.2152, Val Acc: 0.4207
# Epoch  5/20, Train Loss: 1.9957, Val Loss: 2.1219, Val Acc: 0.4672
# Epoch  6/20, Train Loss: 1.8387, Val Loss: 2.0582, Val Acc: 0.4736
# Epoch  7/20, Train Loss: 1.7126, Val Loss: 2.0195, Val Acc: 0.4715
# Epoch  8/20, Train Loss: 1.5901, Val Loss: 1.9860, Val Acc: 0.4926
# Epoch  9/20, Train Loss: 1.4825, Val Loss: 1.9463, Val Acc: 0.5011
# Epoch 10/20, Train Loss: 1.3919, Val Loss: 1.9424, Val Acc: 0.4926
# Epoch 11/20, Train Loss: 1.2889, Val Loss: 1.9010, Val Acc: 0.5095
# Epoch 12/20, Train Loss: 1.2042, Val Loss: 1.8962, Val Acc: 0.5201
# Epoch 13/20, Train Loss: 1.1249, Val Loss: 1.8903, Val Acc: 0.5095
# Epoch 14/20, Train Loss: 1.0425, Val Loss: 1.9009, Val Acc: 0.5412
# Epoch 15/20, Train Loss: 0.9684, Val Loss: 1.8989, Val Acc: 0.5391
# Epoch 16/20, Train Loss: 0.9009, Val Loss: 1.8822, Val Acc: 0.5433
# Epoch 17/20, Train Loss: 0.8377, Val Loss: 1.8958, Val Acc: 0.5391
# Epoch 18/20, Train Loss: 0.7743, Val Loss: 1.9051, Val Acc: 0.5455
# Epoch 19/20, Train Loss: 0.7111, Val Loss: 1.8982, Val Acc: 0.5433
# Epoch 20/20, Train Loss: 0.6615, Val Loss: 1.9198, Val Acc: 0.5370
# GRU Model (Sequence Length 30) Training Time: 3.48 sec, Parameters: 83181
# ------------------------------------------------------------
#
# Final results summary:
# Model: RNN, Sequence Length: 10, Train Loss: 0.7501, Val Loss: 2.0846, Val Acc: 0.4801, Time: 3.00s, Params: 33517
# Model: LSTM, Sequence Length: 10, Train Loss: 0.6846, Val Loss: 2.0020, Val Acc: 0.4969, Time: 3.61s, Params: 108013
# Model: GRU, Sequence Length: 10, Train Loss: 0.6365, Val Loss: 1.9437, Val Acc: 0.5094, Time: 3.05s, Params: 83181
# Model: RNN, Sequence Length: 20, Train Loss: 0.8450, Val Loss: 2.0754, Val Acc: 0.5074, Time: 2.86s, Params: 33517
# Model: LSTM, Sequence Length: 20, Train Loss: 0.8076, Val Loss: 1.9054, Val Acc: 0.5032, Time: 3.49s, Params: 108013
# Model: GRU, Sequence Length: 20, Train Loss: 0.6370, Val Loss: 1.9374, Val Acc: 0.5537, Time: 3.26s, Params: 83181
# Model: RNN, Sequence Length: 30, Train Loss: 0.7858, Val Loss: 2.1023, Val Acc: 0.5095, Time: 2.85s, Params: 33517
# Model: LSTM, Sequence Length: 30, Train Loss: 0.8496, Val Loss: 1.9472, Val Acc: 0.5053, Time: 3.10s, Params: 108013
# Model: GRU, Sequence Length: 30, Train Loss: 0.6615, Val Loss: 1.9198, Val Acc: 0.5370, Time: 3.48s, Params: 83181

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import time
import math
from torch.utils.data import Dataset, DataLoader
import requests

url = "https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt"
response = requests.get(url)
text = response.text

chars = sorted(list(set(text)))
vocab_size = len(chars)
char_to_int = {ch: i for i, ch in enumerate(chars)}
int_to_char = {i: ch for i, ch in enumerate(chars)}

encoded_text = [char_to_int[ch] for ch in text]


def create_sequences_targets(encoded_text, sequence_length):
    sequences = []
    targets = []
    for i in range(0, len(encoded_text) - sequence_length):
        seq = encoded_text[i:i + sequence_length]
        target = encoded_text[i + sequence_length]
        sequences.append(seq)
        targets.append(target)
    sequences = torch.tensor(sequences, dtype=torch.long)
    targets = torch.tensor(targets, dtype=torch.long)
    return sequences, targets


class CharDataset(Dataset):
    def __init__(self, sequences, targets):
        self.sequences = sequences
        self.targets = targets

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, index):
        return self.sequences[index], self.targets[index]


class CharModel(nn.Module):
    def __init__(self, model_type, vocab_size, embed_dim, hidden_size, num_layers=1):
        super(CharModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.model_type = model_type
        if model_type == "LSTM":
            self.rnn = nn.LSTM(embed_dim, hidden_size, num_layers, batch_first=True)
        elif model_type == "GRU":
            self.rnn = nn.GRU(embed_dim, hidden_size, num_layers, batch_first=True)
        else:
            raise ValueError("model_type must be LSTM or GRU")
        self.fc = nn.Linear(hidden_size, vocab_size)

    def forward(self, x):
        x = self.embedding(x)
        if self.model_type == "LSTM":
            out, (h_n, c_n) = self.rnn(x)
        else:
            out, h_n = self.rnn(x)
        out = out[:, -1, :]
        out = self.fc(out)
        return out


def train_epoch(model, dataloader, criterion, optimizer, device):
    model.train()
    total_loss = 0.0
    for inputs, targets in dataloader:
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * inputs.size(0)
    return total_loss / len(dataloader.dataset)


def evaluate_model(model, dataloader, criterion, device):
    model.eval()
    total_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, targets in dataloader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            total_loss += loss.item() * inputs.size(0)
            _, predicted = torch.max(outputs, dim=1)
            correct += (predicted == targets).sum().item()
            total += targets.size(0)
    avg_loss = total_loss / len(dataloader.dataset)
    accuracy = correct / total
    return avg_loss, accuracy


def generate_text(model, seed_text, gen_length, device):
    model.eval()
    generated = seed_text
    input_seq = torch.tensor([char_to_int[ch] for ch in seed_text], dtype=torch.long).unsqueeze(0).to(device)
    with torch.no_grad():
        for _ in range(gen_length):
            output = model(input_seq)
            probs = torch.softmax(output, dim=1).squeeze()
            idx = torch.multinomial(probs, 1).item()
            generated += int_to_char[idx]
            input_seq = torch.cat([input_seq[:, 1:], torch.tensor([[idx]], dtype=torch.long).to(device)], dim=1)
    return generated


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

batch_size = 128
num_epochs = 10
learning_rate = 0.001
embed_dim = 128
hidden_size = 256
num_layers = 2

results = {}

for seq_length in [20, 30, 50]:
    print(f"\n=== Sequence Length = {seq_length} ===")
    sequences, targets = create_sequences_targets(encoded_text, seq_length)
    dataset = CharDataset(sequences, targets)
    train_size = int(len(dataset) * 0.8)
    test_size = len(dataset) - train_size
    train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])
    train_loader = DataLoader(train_dataset, shuffle=True, batch_size=batch_size)
    test_loader = DataLoader(test_dataset, shuffle=False, batch_size=batch_size)

    for model_type in ["LSTM", "GRU"]:
        print(f"\n--- Training Model: {model_type} ---")
        model = CharModel(model_type, vocab_size, embed_dim, hidden_size, num_layers=num_layers).to(device)
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)
        criterion = nn.CrossEntropyLoss()

        start_time = time.time()
        for epoch in range(num_epochs):
            train_loss = train_epoch(model, train_loader, criterion, optimizer, device)
            val_loss, val_acc = evaluate_model(model, test_loader, criterion, device)
            perplexity = math.exp(val_loss)
            print(f"Epoch {epoch + 1:2d}/{num_epochs}, Train Loss: {train_loss:.4f}, " +
                  f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}, Perplexity: {perplexity:.2f}")
        elapsed_time = time.time() - start_time

        num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

        results[(model_type, seq_length)] = {
            "train_loss": train_loss,
            "val_loss": val_loss,
            "val_acc": val_acc,
            "perplexity": perplexity,
            "time": elapsed_time,
            "num_params": num_params
        }
        print(
            f"{model_type} Model (Sequence Length {seq_length}) Training Time: {elapsed_time:.2f} sec, Parameters: {num_params}")

        seed = "The "
        generated = generate_text(model, seed, 100, device)
        print("Generated Text Example:")
        print(generated)
        print("-" * 60)

print("\n=== Experiment Results Summary ===")
for key, res in results.items():
    model_type, seq_length = key
    print(f"Model: {model_type:4s}, Sequence Length: {seq_length:2d}, Final Train Loss: {res['train_loss']:.4f}, " +
          f"Final Val Loss: {res['val_loss']:.4f}, Val Acc: {res['val_acc']:.4f}, " +
          f"Perplexity: {res['perplexity']:.2f}, Time: {res['time']:.2f}s, Params: {res['num_params']}")
# Out:
# Device: cuda
#
# === Sequence Length = 20 ===
#
# --- Training Model: LSTM ---
# Epoch  1/10, Train Loss: 1.6668, Val Loss: 1.4746, Val Acc: 0.5505, Perplexity: 4.37
# Epoch  2/10, Train Loss: 1.4084, Val Loss: 1.3955, Val Acc: 0.5698, Perplexity: 4.04
# Epoch  3/10, Train Loss: 1.3446, Val Loss: 1.3628, Val Acc: 0.5775, Perplexity: 3.91
# Epoch  4/10, Train Loss: 1.3073, Val Loss: 1.3500, Val Acc: 0.5822, Perplexity: 3.86
# Epoch  5/10, Train Loss: 1.2809, Val Loss: 1.3392, Val Acc: 0.5860, Perplexity: 3.82
# Epoch  6/10, Train Loss: 1.2602, Val Loss: 1.3353, Val Acc: 0.5857, Perplexity: 3.80
# Epoch  7/10, Train Loss: 1.2432, Val Loss: 1.3356, Val Acc: 0.5868, Perplexity: 3.80
# Epoch  8/10, Train Loss: 1.2292, Val Loss: 1.3335, Val Acc: 0.5872, Perplexity: 3.79
# Epoch  9/10, Train Loss: 1.2172, Val Loss: 1.3341, Val Acc: 0.5872, Perplexity: 3.80
# Epoch 10/10, Train Loss: 1.2067, Val Loss: 1.3307, Val Acc: 0.5905, Perplexity: 3.78
# LSTM Model (Sequence Length 20) Training Time: 551.66 sec, Parameters: 946625
# Generated Text Example:
# The dismaachinm the diss3&Le3wZa3YF &upt,
# And Marce;
# Till they, okee.
#
# VOLe Warw,
# Ridend;
# O, how all Ric
# ------------------------------------------------------------
#
# --- Training Model: GRU ---
# Epoch  1/10, Train Loss: 1.6338, Val Loss: 1.4736, Val Acc: 0.5522, Perplexity: 4.36
# Epoch  2/10, Train Loss: 1.4273, Val Loss: 1.4308, Val Acc: 0.5615, Perplexity: 4.18
# Epoch  3/10, Train Loss: 1.3870, Val Loss: 1.4162, Val Acc: 0.5654, Perplexity: 4.12
# Epoch  4/10, Train Loss: 1.3688, Val Loss: 1.4026, Val Acc: 0.5708, Perplexity: 4.07
# Epoch  5/10, Train Loss: 1.3591, Val Loss: 1.4052, Val Acc: 0.5682, Perplexity: 4.08
# Epoch  6/10, Train Loss: 1.3537, Val Loss: 1.3991, Val Acc: 0.5703, Perplexity: 4.05
# Epoch  7/10, Train Loss: 1.3532, Val Loss: 1.4062, Val Acc: 0.5687, Perplexity: 4.08
# Epoch  8/10, Train Loss: 1.3541, Val Loss: 1.4089, Val Acc: 0.5690, Perplexity: 4.09
# Epoch  9/10, Train Loss: 1.3571, Val Loss: 1.4105, Val Acc: 0.5677, Perplexity: 4.10
# Epoch 10/10, Train Loss: 1.3607, Val Loss: 1.4176, Val Acc: 0.5656, Perplexity: 4.13
# GRU Model (Sequence Length 20) Training Time: 458.74 sec, Parameters: 716225
# Generated Text Example:
# The muster--
# And grimD
# Withankful,
# But, as with'd withed which with more:
# No, look'sn God, I will,
# We wa
# ------------------------------------------------------------
#
# === Sequence Length = 30 ===
#
# --- Training Model: LSTM ---
# Epoch  1/10, Train Loss: 1.6620, Val Loss: 1.4735, Val Acc: 0.5508, Perplexity: 4.36
# Epoch  2/10, Train Loss: 1.4011, Val Loss: 1.3899, Val Acc: 0.5710, Perplexity: 4.01
# Epoch  3/10, Train Loss: 1.3351, Val Loss: 1.3611, Val Acc: 0.5792, Perplexity: 3.90
# Epoch  4/10, Train Loss: 1.2957, Val Loss: 1.3455, Val Acc: 0.5847, Perplexity: 3.84
# Epoch  5/10, Train Loss: 1.2684, Val Loss: 1.3318, Val Acc: 0.5878, Perplexity: 3.79
# Epoch  6/10, Train Loss: 1.2465, Val Loss: 1.3239, Val Acc: 0.5912, Perplexity: 3.76
# Epoch  7/10, Train Loss: 1.2290, Val Loss: 1.3239, Val Acc: 0.5910, Perplexity: 3.76
# Epoch  8/10, Train Loss: 1.2142, Val Loss: 1.3216, Val Acc: 0.5922, Perplexity: 3.75
# Epoch  9/10, Train Loss: 1.2015, Val Loss: 1.3215, Val Acc: 0.5944, Perplexity: 3.75
# Epoch 10/10, Train Loss: 1.1900, Val Loss: 1.3230, Val Acc: 0.5938, Perplexity: 3.75
# LSTM Model (Sequence Length 30) Training Time: 775.39 sec, Parameters: 946625
# Generated Text Example:
# The play;
# Richan faces, with oath,
# Which my
# beforce's might;
# From some,
# Hathe woe!' Stantish, Juda3iIS3
#
# ------------------------------------------------------------
#
# --- Training Model: GRU ---
# Epoch  1/10, Train Loss: 1.6269, Val Loss: 1.4809, Val Acc: 0.5476, Perplexity: 4.40
# Epoch  2/10, Train Loss: 1.4178, Val Loss: 1.4295, Val Acc: 0.5631, Perplexity: 4.18
# Epoch  3/10, Train Loss: 1.3773, Val Loss: 1.4077, Val Acc: 0.5698, Perplexity: 4.09
# Epoch  4/10, Train Loss: 1.3581, Val Loss: 1.4030, Val Acc: 0.5692, Perplexity: 4.07
# Epoch  5/10, Train Loss: 1.3499, Val Loss: 1.4030, Val Acc: 0.5697, Perplexity: 4.07
# Epoch  6/10, Train Loss: 1.3449, Val Loss: 1.3996, Val Acc: 0.5709, Perplexity: 4.05
# Epoch  7/10, Train Loss: 1.3432, Val Loss: 1.4017, Val Acc: 0.5719, Perplexity: 4.06
# Epoch  8/10, Train Loss: 1.3434, Val Loss: 1.4036, Val Acc: 0.5715, Perplexity: 4.07
# Epoch  9/10, Train Loss: 1.3461, Val Loss: 1.4000, Val Acc: 0.5715, Perplexity: 4.06
# Epoch 10/10, Train Loss: 1.3477, Val Loss: 1.4117, Val Acc: 0.5685, Perplexity: 4.10
# GRU Model (Sequence Length 30) Training Time: 633.89 sec, Parameters: 716225
# Generated Text Example:
# The chane marrying Frothed yond.
#
# LADY?
#
# PEtr-Lades;
# Sinchanes:
# My min
# Of worth.
#
# CAGuU Henriture apot:
#
# ------------------------------------------------------------
#
# === Sequence Length = 50 ===
#
# --- Training Model: LSTM ---
# Epoch  1/10, Train Loss: 1.6551, Val Loss: 1.4524, Val Acc: 0.5564, Perplexity: 4.27
# Epoch  2/10, Train Loss: 1.3895, Val Loss: 1.3824, Val Acc: 0.5750, Perplexity: 3.98
# Epoch  3/10, Train Loss: 1.3231, Val Loss: 1.3479, Val Acc: 0.5843, Perplexity: 3.85
# Epoch  4/10, Train Loss: 1.2833, Val Loss: 1.3280, Val Acc: 0.5905, Perplexity: 3.77
# Epoch  5/10, Train Loss: 1.2550, Val Loss: 1.3159, Val Acc: 0.5940, Perplexity: 3.73
# Epoch  6/10, Train Loss: 1.2327, Val Loss: 1.3126, Val Acc: 0.5950, Perplexity: 3.72
# Epoch  7/10, Train Loss: 1.2156, Val Loss: 1.3056, Val Acc: 0.5977, Perplexity: 3.69
# Epoch  8/10, Train Loss: 1.2005, Val Loss: 1.3078, Val Acc: 0.5972, Perplexity: 3.70
# Epoch  9/10, Train Loss: 1.1883, Val Loss: 1.3053, Val Acc: 0.5977, Perplexity: 3.69
# Epoch 10/10, Train Loss: 1.1776, Val Loss: 1.3072, Val Acc: 0.5978, Perplexity: 3.70
# LSTM Model (Sequence Length 50) Training Time: 1231.18 sec, Parameters: 946625
# Generated Text Example:
# The with.Qx$QQQ3$3$$3$33$33$333$$$Q33333333333333$33$$$QQ$3$$Q333$$$Q3QQ$3$$QQ$Q$$$$$$$$$Q$$Q$3$$3$3$33$
# ------------------------------------------------------------
#
# --- Training Model: GRU ---
# Epoch  1/10, Train Loss: 1.6188, Val Loss: 1.4611, Val Acc: 0.5544, Perplexity: 4.31
# Epoch  2/10, Train Loss: 1.4075, Val Loss: 1.4097, Val Acc: 0.5670, Perplexity: 4.09
# Epoch  3/10, Train Loss: 1.3643, Val Loss: 1.3933, Val Acc: 0.5740, Perplexity: 4.03
# Epoch  4/10, Train Loss: 1.3445, Val Loss: 1.3928, Val Acc: 0.5724, Perplexity: 4.03
# Epoch  5/10, Train Loss: 1.3351, Val Loss: 1.3828, Val Acc: 0.5767, Perplexity: 3.99
# Epoch  6/10, Train Loss: 1.3302, Val Loss: 1.3845, Val Acc: 0.5759, Perplexity: 3.99
# Epoch  7/10, Train Loss: 1.3289, Val Loss: 1.3854, Val Acc: 0.5777, Perplexity: 4.00
# Epoch  8/10, Train Loss: 1.3287, Val Loss: 1.3895, Val Acc: 0.5750, Perplexity: 4.01
# Epoch  9/10, Train Loss: 1.3320, Val Loss: 1.3934, Val Acc: 0.5757, Perplexity: 4.03
# Epoch 10/10, Train Loss: 1.3354, Val Loss: 1.3907, Val Acc: 0.5757, Perplexity: 4.02
# GRU Model (Sequence Length 50) Training Time: 995.41 sec, Parameters: 716225
# Generated Text Example:
# The fair, swears it.
#
# FLRedy forth youngly,
# Thou comfort LuvON:
# You abgings is begingne;
# Loience:
# Canks:
# ------------------------------------------------------------
#
# === Experiment Results Summary ===
# Model: LSTM, Sequence Length: 20, Final Train Loss: 1.2067, Final Val Loss: 1.3307, Val Acc: 0.5905, Perplexity: 3.78, Time: 551.66s, Params: 946625
# Model: GRU , Sequence Length: 20, Final Train Loss: 1.3607, Final Val Loss: 1.4176, Val Acc: 0.5656, Perplexity: 4.13, Time: 458.74s, Params: 716225
# Model: LSTM, Sequence Length: 30, Final Train Loss: 1.1900, Final Val Loss: 1.3230, Val Acc: 0.5938, Perplexity: 3.75, Time: 775.39s, Params: 946625
# Model: GRU , Sequence Length: 30, Final Train Loss: 1.3477, Final Val Loss: 1.4117, Val Acc: 0.5685, Perplexity: 4.10, Time: 633.89s, Params: 716225
# Model: LSTM, Sequence Length: 50, Final Train Loss: 1.1776, Final Val Loss: 1.3072, Val Acc: 0.5978, Perplexity: 3.70, Time: 1231.18s, Params: 946625
# Model: GRU , Sequence Length: 50, Final Train Loss: 1.3354, Final Val Loss: 1.3907, Val Acc: 0.5757, Perplexity: 4.02, Time: 995.41s, Params: 716225
